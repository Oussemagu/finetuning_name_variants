# %%
# !pip install qdrant-client pyngrok
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.7/327.7 kB 9.7 MB/s eta 0:00:00
# ...

# %%
# !pip install mistral_inference transformers sentencepiece accelerate bitsandbytes python-dotenv huggingface_hub langchain-community langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 83.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 59.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...

# %%
from pyngrok import ngrok

# %%
# !ngrok authtoken your_ngrk_token
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from qdrant_client import QdrantClient

# Met ton URL ngrok HTTPS ou HTTP ici
ngrok_host = "your_host_without_http/"
ngrok_url = f"http://{ngrok_host}"

#client = QdrantClient(url=ngrok_url)
client = QdrantClient(
    host=ngrok_host,
    port=443,  # Ngrok HTTPS uses 443
    https=True,  # Explicitly enable HTTPS
    timeout=30
)
# Test the connection
try:
    response = client.get_collections()
    print("Connection successful! Collections:", response.collections)
except Exception as e:
    print("Qdrant connection failed. Full error:")
    print(f"Type: {type(e)}")
    print(f"Details: {str(e)}")
    if hasattr(e, 'details'):  # For gRPC errors
        print(f"gRPC details: {e.details()}")
# Out:
# <ipython-input-5-4c6dfe948a55>:8: UserWarning: Failed to obtain server version. Unable to check client-server compatibility. Set check_compatibility=False to skip version check.
#   client = QdrantClient(
# Connection successful! Collections: [CollectionDescription(name='my_books'), CollectionDescription(name='names_of_vectors_with_concatenation_hybrid'), CollectionDescription(name='names_of_vectors_with_concatenation'), CollectionDescription(name='names_of_vectors1'), CollectionDescription(name='names_of_vectors_with_concatenation_sparse'), CollectionDescription(name='names_of_vectors'), CollectionDescription(name='my_collection')]

# %%
from huggingface_hub import login
login(token="fake_token_give_your_own_token")

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.3")
model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.3",
    load_in_8bit=True,  # Enable 8-bit quantization
    device_map="auto",)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/141k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# ...

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

qdrant_embeddings = HuggingFaceEmbeddings(
    model_name="paraphrase-multilingual-MiniLM-L12-v2"
)
# Out:
# <ipython-input-9-8e19f1d5e1a0>:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   qdrant_embeddings = HuggingFaceEmbeddings(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# ...

# %%
# !pip install langchain_qdrant

# %%
from langchain_community.vectorstores import Qdrant
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
nrok_url="give_your_ngrok_url_with_http"

vector_store = QdrantVectorStore.from_existing_collection(
    embedding=qdrant_embeddings,
    collection_name="names_of_vectors_with_concatenation",
    location="194b-41-225-170-87.ngrok-free.app",  # Hostname without protocol
    port=443,
    https=True,
    prefer_grpc=False,
    timeout=10
)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# <ipython-input-13-17a1d9db2f04> in <cell line: 0>()
#       4 nrok_url="https://dd15-41-225-154-105.ngrok-free.app/"
#       5
# ----> 6 vector_store = QdrantVectorStore.from_existing_collection(
#       7     embedding=qdrant_embeddings,
#       8     collection_name="names_of_vectors_with_concatenation",
#
# /usr/local/lib/python3.11/dist-packages/langchain_qdrant/qdrant.py in from_existing_collection(cls, collection_name, embedding, retrieval_mode, location, url, port, grpc_port, prefer_grpc, https, api_key, prefix, timeout, host, path, distance, content_payload_key, metadata_payload_key, vector_name, sparse_vector_name, sparse_embedding, validate_embeddings, validate_collection_config, **kwargs)
#     410         )
#     411
# --> 412         return cls(
#     413             client=client,
# ...

# %%
from pydantic import BaseModel, Field
from typing import List

class OrthographicVariations(BaseModel):
    Latin: List[str] = Field(description="Three distinct Latin script variations", min_items=3, max_items=3)
    Cyrillic: List[str] = Field(description="Three distinct Cyrillic script variations", min_items=3, max_items=3)
    Arabic: List[str] = Field(description="Three distinct Arabic script variations", min_items=3, max_items=3)

class NameTransliterationOutput(BaseModel):
    Orthographic_Variations: OrthographicVariations

# %%
from langchain.prompts import PromptTemplate,ChatPromptTemplate
from langchain.output_parsers import StructuredOutputParser
from langchain_core.output_parsers import JsonOutputParser
from langchain.output_parsers import PydanticOutputParser # Updated import

output_parser = PydanticOutputParser(pydantic_object=NameTransliterationOutput)
# Define the prompt template
prompt_template="""
[INST] You are a multilingual name transliteration expert. Your task is to generate orthographic variations for names, using either provided context or your own knowledge.

Retrieved context (if any):
{context}

User input name: {name}

Instructions:
1. If relevant context is provided (contains matching names), use it to generate variations
2. If context is empty/irrelevant, use your own linguistic knowledge to generate plausible variations
3. Always generate exactly three variations for each requested script:
   - Latin
   - Cyrillic
   - Arabic
4. Variations must be culturally appropriate and consistent with naming conventions

Output format:
Retrieved Records: [List matching records if found, otherwise "No relevant records found"]
Orthographic Variations:
Latin: [Variation 1], [Variation 2], [Variation 3]
Cyrillic: [Variation 1], [Variation 2], [Variation 3]
Arabic: [Variation 1], [Variation 2], [Variation 3]

Examples:
Example 1 (with relevant context):
Retrieved context: Primary Name: Aleksandr Petrov, Aliases: [Александр Петров, Alex Petrov]
User input: Aleksandr
Output:
Retrieved Records: Primary Name: Aleksandr Petrov, Aliases: [Александр Петров, Alex Petrov]
Orthographic Variations:
Latin: Alexander, Aleksandar, Alekzandr
Cyrillic: Александр, Александар, Алекзандр
Arabic: أليكسندر, ألكسندر, ألكساند

Example 2 (no relevant context):
Retrieved context: Primary Name: Juan Martinez, Aliases: [Хуан Мартинес, خوان مارتينيز]
User input: Oussema
Output:
Retrieved Records: No relevant records found
Orthographic Variations:
Latin: Oussema, Usama, Oussama
Cyrillic: Усема, Уссама, Усама
Arabic:  أسامة
[/INST]"""


# Test names
test_names = ["sawsen bent foulenn"]
# 3. Create the prompt template correctly
prompt = PromptTemplate.from_template(prompt_template)

# %%
from langchain.schema.runnable import RunnablePassthrough, RunnableLambda

def print_docs(docs):
    print("=== Retrieved Documents ===")
    for i, doc in enumerate(docs, 1):
        print(f"\nDocument {i}:")
        print(f"Source: {doc.metadata.get('source', 'N/A')}")
        print(f"Content: {doc.page_content[:200]}...")  # Print first 200 chars
    return docs

# %%
input_ids = tokenizer("hello", return_tensors="pt").input_ids
output = model.generate(input_ids,return)
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-2097bdd13abf> in <cell line: 0>()
#       1 input_ids = tokenizer("hello", return_tensors="pt").input_ids
# ----> 2 output = model.generate(input_ids,return_tensor="pt")
#       3 generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
#       4 print(generated_text)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ...

# %%
response = rag_chain.invoke("amine")
print(response.content)
# Out:
# === Retrieved Documents ===
#
# Document 1:
# Source: final_target_1
# Content: ISIM Amin Limited...
#
# Document 2:
# Source: final_target_3
# Content: ASHER...
#
# Document 3:
# Source: final_target_3
# Content: Assadollah Asadi...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-a5b3d44eefcb> in <cell line: 0>()
# ----> 1 response = rag_chain.invoke("amine")
#       2 print(response.content)
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    3045                         input = context.run(step.invoke, input, config, **kwargs)
#    3046                     else:
# -> 3047                         input = context.run(step.invoke, input, config)
#    3048         # finish the root run
#    3049         except BaseException as e:
#
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

# 1. First ensure your model is properly wrapped for LangChain
# If using a custom model, you might need:
# from langchain.llms import YourModelWrapper
# model = YourModelWrapper(your_model)

# 2. Define the prompt template correctly
prompt = ChatPromptTemplate.from_messages([
    ("system", """You are a multilingual name transliteration expert..."""),
    ("human", "Generate name variants for: {input}")
])

# 3. Simplified processing chain
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

rag_chain = (
    {
        "context": retriever | format_docs,
        "input": RunnablePassthrough()
    }
    | prompt
    | model
    | output_parser
)

# 4. Proper invocation
try:
    response = rag_chain.invoke("amine")  # Just the raw input
    print(response)
except Exception as e:
    print(f"Error: {e}")
    print("Check that:")
    print("1. Your model accepts ChatPromptValue inputs")
    print("2. All components in the chain are compatible")
# Out:
# Error: embedding(): argument 'indices' (position 2) must be Tensor, not ChatPromptValue
# Check that:
# 1. Your model accepts ChatPromptValue inputs
# 2. All components in the chain are compatible

# %%
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

# Assuming these are defined elsewhere:
# - NameTransliterationOutput (your Pydantic model)
# - vector_store (your Qdrant vector store)
# - model (your LLM model)

# 1. Initialize output parser
output_parser = PydanticOutputParser(pydantic_object=NameTransliterationOutput)

# 2. Define the prompt template (unchanged)
prompt_template = """
You are a multilingual name transliteration expert. Your task is to generate orthographic variations for names, using either provided context or your own knowledge.

Retrieved context (if any):
{context}

User input name: {name}

[Rest of your template remains exactly the same...]
"""

# 3. Create the prompt template
prompt = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "name"],
)

# 4. Document processing function
def process_docs(docs):
    """Format the retrieved documents into a single string"""
    return "\n".join([f"Document {i+1}:\n{doc.page_content}" for i, doc in enumerate(docs)])

# 5. Build the chain
retriever = vector_store.as_retriever(search_kwargs={"k": 3})

rag_chain = (
    {
        "context": retriever | process_docs,
        "name": RunnablePassthrough()
    }
    | prompt
    | model
    | output_parser
)

# 6. Test the chain
try:
    response = rag_chain.invoke("amine")  # Just the name without "generate variants for"
    print(response)  # This will print the parsed Pydantic object
except Exception as e:
    print(f"Error occurred: {str(e)}")
# Out:
# Error occurred: embedding(): argument 'indices' (position 2) must be Tensor, not StringPromptValue

# %%
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
if tokenizer.pad_token is None:
    tokenizer.add_special_tokens({'pad_token': '[PAD]'})
# 1. Initialize components
output_parser = PydanticOutputParser(pydantic_object=NameTransliterationOutput)

# 2. Define the prompt template (unchanged content)
prompt_template = """[your exact template content here]"""

# 3. Create the prompt with proper variable handling
prompt = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "name"],
    partial_variables={"format_instructions": output_parser.get_format_instructions()}
)

# 4. Document processor that maintains the chain
def format_docs(docs):
    return "\n".join(doc.page_content for doc in docs)


def prepare_model_inputs(text):
    encoding = tokenizer(
        text,
        return_tensors="pt",
        padding=True,
        truncation=True,
        max_length=512
    )
    # Convert BatchEncoding to tuple of tensors expected by your model
    return (encoding['input_ids'], encoding['attention_mask'])

# 5. Chain construction with model compatibility
rag_chain = (
    {
        "context": retriever | format_docs,
        "name": RunnablePassthrough()
    }
    | prompt
    | (lambda x: x.text)  # Convert StringPromptValue to text
    |prepare_model_inputs
    | model  # Your model should accept raw text input
    | output_parser
)

# 6. Safe execution
try:
    response = rag_chain.invoke("amine")  # Just the name
    print(response)  # Parsed output
except Exception as e:
    print(f"Execution error: {str(e)}")
    print("Please verify:")
    print("- Your model accepts raw text input")
    print("- The vector store returns valid documents")
    print("- Your output parser matches the model's output")
# Out:
# Execution error: embedding(): argument 'indices' (position 2) must be Tensor, not tuple
# Please verify:
# - Your model accepts raw text input
# - The vector store returns valid documents
# - Your output parser matches the model's output

# %%
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# 4. Simple prompt template (using Mistral's instruction format)
prompt_template =   template="""
[INST] You are a multilingual name transliteration expert. Your task is to generate orthographic variations for a user-provided name {name}.

User input name: {name}

Instructions:
1. Generate exactly three orthographic variations of the input name for each of the following scripts:
   - Latin
   - Cyrillic
   - Arabic
2. Ensure variations are plausible, culturally appropriate, and consistent with the input name.
3. If the input name is ambiguous (e.g., a single name like "Said"), make reasonable assumptions about its origin or context to produce accurate transliterations.
4. Do not invent names or scripts not requested.

6. Do not include any text outside the JSON object.

Examples:
1. User input name: Aleksandr Petrov
```json
   {{
  "Orthographic_Variations": {{
    "Latin": ["Alexander Petrov", "Alekzandr Petroff", "Alyaksandr Petrou"],
    "Cyrillic": ["Александр Петров", "Александар Пятров", "Аляксандр Пятроў"],
    "Arabic": ["ألكسندر بتروف", "أليكسندر بيتروف", "أليكسندار بيتروف"]
  }}
}}


2. User input name: فاطمة الزهراء
   {{
  "Orthographic_Variations": {{
    "Latin": ["Fatima Al-Zahra", "Faatimah Az-Zahraa", "Fatma Zahraa"],
    "Cyrillic": ["Фатима Аз-Захра", "Фатма Аль-Захраа", "Фатыма Аз-Захра"],
    "Arabic": ["فاطمة الزهراء", "فاطمه الزهراء", "فاطما الزهراء"]
  }}
}}

3. User input name: Саид Петр
   {{
  "Orthographic_Variations": {{
    "Latin": ["Said Petr", "Sayed Pyotr", "Sayid Petar"],
    "Cyrillic": ["Саид Пётр", "Сайд Петар", "Сайид Пьотр"],
    "Arabic": ["سعيد بطرس", "سيد بطرس", "سعيّد بطرس"]
  }}
}}
[/INST]
"""
prompt = PromptTemplate.from_template(prompt_template)

# 5. Model processing function
def generate_response(inputs):
    # Convert LangChain output to model inputs
    text = inputs.text if hasattr(inputs, 'text') else inputs
    inputs = tokenizer(text, return_tensors="pt", padding=True).to("cuda")

    # Generate output
    outputs = model.generate(
        **inputs,
        max_new_tokens=200,
        temperature=0.7,
        do_sample=True
    )

    # Decode and clean output
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# 6. Simple chain
chain = (
    {"name": RunnablePassthrough()}
    | prompt
    | generate_response
)

# 7. Test execution
try:
    result = chain.invoke("amine")
    print("Generated variants:\n", result)
except Exception as e:
    print("Error:", str(e))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generated variants:
#
#  You are a multilingual name transliteration expert. Your task is to generate orthographic variations for a user-provided name amine.
#
# User input name: amine
#
# Instructions:
# 1. Generate exactly three orthographic variations of the input name for each of the following scripts:
#    - Latin
#    - Cyrillic
#    - Arabic
# 2. Ensure variations are plausible, culturally appropriate, and consistent with the input name.
# 3. If the input name is ambiguous (e.g., a single name like "Said"), make reasonable assumptions about its origin or context to produce accurate transliterations.
# 4. Do not invent names or scripts not requested.
#
# 6. Do not include any text outside the JSON object.
#
# Examples:
# 1. User input name: Aleksandr Petrov
# ```json
#    {
#   "Orthographic_Variations": {
#     "Latin": ["Alexander Petrov", "Alekzandr Petroff", "Alyaksandr Petrou"],
# ...

# %%
# !pip install langchain_huggingface

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline
from langchain_huggingface import HuggingFacePipeline
pipe = pipeline("text-generation",
                model=model,
                model_kwargs={
                 "device_map": "auto",
                 "torch_dtype": torch.float16,
                  "memory_cleanup": True  # Some custom implementations support this
    }
                tokenizer=tokenizer,
                max_new_tokens=512,
                temperature=0.5,
                do_sample=True)
# Out:
# Device set to use cuda:0

# %%
llm = HuggingFacePipeline(pipeline=pipe)

# %%
from langchain.schema.runnable import RunnablePassthrough
retriever = vector_store.as_retriever(search_kwargs={"k": 3})  # Top 3 relevant chunks

rag_chain = (
    {"context": retriever | RunnableLambda(print_docs), "name": RunnablePassthrough()}
    | prompt
    | model
)

# %%
# 3. Simplified processing chain
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
import torch

# %%
# Add these before chain execution
torch.backends.cuda.enable_flash_sdp(True)  # Enable flash attention
torch.set_grad_enabled(False)                # Disable gradient calculation

# For CUDA-specific optimizations
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    torch.cuda.reset_peak_memory_stats()

# %%
from langchain_huggingface import HuggingFacePipeline
from langchain.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough


# 2. Configure tokenizer
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token


# 4. Simple prompt template (using Mistral's instruction format)
prompt_template=""" [INST]
    You are a multilingual name transliteration expert. Your task is to process a user-provided name and optional context from a database to generate orthographic variations.

    Retrieved context (if any):
    {context}

    User input name: {query}

    Instructions:
    1. If context is provided, list the retrieved records.
    2. Generate exactly three orthographic variations of the input name in the following scripts:
       - Latin
       - Cyrillic
       - Arabic
    3. If no context is provided, generate variations based solely on the input name.
    4. Ensure variations are plausible, culturally appropriate, and consistent with the input or context.
    5. If the input name is ambiguous (e.g ascended to one another), use context (if available) to infer the full name, or make reasonable assumptions.
    6. Do not invent names or scripts not requested.
    7. Format the output as follows:
       Retrieved Records:
       [List records here, or "None" if no context]
       Orthographic Variations:
       - Latin: [Variation]
       - Cyrillic: [Variation]
       - Arabic: [Variation]

    Examples:
    1. Retrieved context:  Aleksandr Muskati, Александр Хавьер , Fahim Petrou
       Output:
       User input name: Aleksandr Petrov
       Retrieved Records:  Aleksandr Muskati, Александр Хавьер , Fahim Petrou
       Orthographic Variations:
       - Latin: ["Alexander Petrov", "Alekzandr Petroff", "Alyaksandr Petrou"]
       - Cyrillic: ["Александр Петров", "Александар Пятров", "Аляксандр Пятроў"]
       - Arabic: ["ألكسندر بيتروف", "أليكسندر بيتروف", "أليكسندار بيترىف"]

    2. Retrieved context: None
       Output:
       User input name: Fatima alZahra

       Retrieved Records:
       None
       Orthographic Variations:
       - Latin: ["Fatima Al-Zahra", "Faatimah Az-Zahraa", "Fatma Zahraa"]
       - Cyrillic: ["Фатима Аз-Захра", "Фатма Аль-Захраа", "Фатыма Аз-Захра"]
       - Arabic : ["فاطمة الزهراء", "فاطمه الزهراء", "فاطما الزهراء"]


    3. Retrieved context:  saied bemoussa , hakim boutros , amal Petar , Manel Boutros
       Output:
       User input name: Саид Петр
       Retrieved Records:  saied bemoussa , hakim boutros , amal Petar , Manel Boutros
       Orthographic Variations:
       - Latin: ["Said Petr", "Sayed Pyotr", "Sayid Petar"]
       - "Cyrillic": ["Саид Пётр", "Сайд Петар", "Сайид Пьотр"],
       - Arabic: ["سعيد بطرس", "سيد بطرس", "سعيّد بطرس"]
[/INST]

    """

prompt = PromptTemplate.from_template(prompt_template)
# 3. Simplified processing chain
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# 6. Simple test chain
name_chain = (
    {"query": RunnablePassthrough(),"context": retriever |format_docs}
    | prompt
    | llm
)

result = name_chain.invoke("Mohammed aziz agha")
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  [INST]
#     You are a multilingual name transliteration expert. Your task is to process a user-provided name and optional context from a database to generate orthographic variations.
#
#     Retrieved context (if any):
#     Mohammad Nazar Azimi | محمد نظر عظیمی
#
# Mohammad Nazar Azimi | محمد نظر عظیمی
#
# DOST MOHAMMAD | Doost Mohammad | دوست محمد
#
#     User input name: Mohammed aziz agha
#
#     Instructions:
#     1. If context is provided, list the retrieved records.
#     2. Generate exactly three orthographic variations of the input name in the following scripts:
#        - Latin
#        - Cyrillic
#        - Arabic
#     3. If no context is provided, generate variations based solely on the input name.
#     4. Ensure variations are plausible, culturally appropriate, and consistent with the input or context.
# ...
